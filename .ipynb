# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cancer = pd.read_csv(r"C:\Users\HP\Desktop\projects\breastcancer\breast-cancer.csv")
cancer.head()
cancer.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
cancer.info()
print(cancer.keys())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
sns.countplot(cancer.diagnosis)

# %%
cancer.corr #to find correlation
# Out:
# <bound method DataFrame.corr of            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
cancer.drop(['Unnamed: 32','id'],axis = 1,inplace = True)

# %%
cancer.head()
# Out:
#   diagnosis  texture_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0         M         10.38          0.11840           0.27760          0.3001
# 1         M         17.77          0.08474           0.07864          0.0869
# 2         M         21.25          0.10960           0.15990          0.1974
# 3         M         20.38          0.14250           0.28390          0.2414
# 4         M         14.34          0.10030           0.13280          0.1980
#
#    symmetry_mean  fractal_dimension_mean  texture_se  smoothness_se  \
# 0         0.2419                 0.07871      0.9053       0.006399
# 1         0.1812                 0.05667      0.7339       0.005225
# 2         0.2069                 0.05999      0.7869       0.006150
# 3         0.2597                 0.09744      1.1560       0.009110
# 4         0.1809                 0.05883      0.7813       0.011490
#
#    compactness_se  ...  concave points_se  symmetry_se  fractal_dimension_se  \
# ...

# %%
plt.figure(figsize = (25,25))
sns.heatmap(cancer.corr(method = 'pearson'),annot = True , cmap = 'Blues')

# %%
cancer.drop(['radius_mean','perimeter_mean','area_mean','concave points_mean','radius_se','perimeter_se',\
             'area_se','radius_worst','perimeter_worst','area_worst'] , axis=1,inplace = True)

# %%
cancer.head()
# Out:
#   diagnosis  texture_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0         M         10.38          0.11840           0.27760          0.3001
# 1         M         17.77          0.08474           0.07864          0.0869
# 2         M         21.25          0.10960           0.15990          0.1974
# 3         M         20.38          0.14250           0.28390          0.2414
# 4         M         14.34          0.10030           0.13280          0.1980
#
#    symmetry_mean  fractal_dimension_mean  texture_se  smoothness_se  \
# 0         0.2419                 0.07871      0.9053       0.006399
# 1         0.1812                 0.05667      0.7339       0.005225
# 2         0.2069                 0.05999      0.7869       0.006150
# 3         0.2597                 0.09744      1.1560       0.009110
# 4         0.1809                 0.05883      0.7813       0.011490
#
#    compactness_se  ...  concave points_se  symmetry_se  fractal_dimension_se  \
# ...

# %%
plt.figure(figsize = (20,25))
sns.heatmap(cancer.corr(method = 'pearson'),annot = True ,cmap = 'Blues' )

# %% [markdown]
# ### split feature and target variable

# %%
target = cancer.diagnosis
feature = cancer.drop('diagnosis' ,axis = 1)
feature.head()
# Out:
#    texture_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0         10.38          0.11840           0.27760          0.3001
# 1         17.77          0.08474           0.07864          0.0869
# 2         21.25          0.10960           0.15990          0.1974
# 3         20.38          0.14250           0.28390          0.2414
# 4         14.34          0.10030           0.13280          0.1980
#
#    symmetry_mean  fractal_dimension_mean  texture_se  smoothness_se  \
# 0         0.2419                 0.07871      0.9053       0.006399
# 1         0.1812                 0.05667      0.7339       0.005225
# 2         0.2069                 0.05999      0.7869       0.006150
# 3         0.2597                 0.09744      1.1560       0.009110
# 4         0.1809                 0.05883      0.7813       0.011490
#
#    compactness_se  concavity_se  concave points_se  symmetry_se  \
# 0         0.04904       0.05373            0.01587      0.03003
# ...

# %%
target.head()
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# Name: diagnosis, dtype: object

# %%
features = (feature - feature.mean())/(feature.max()-feature.min())

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 6)
pca.fit(features)

final_data = pca.transform(features)
final_data = pd.DataFrame(final_data,columns = ['Dimension 1','Dimension 2','Dimension 3',\
                                                 'Dimension 4','Dimension 5','Dimension 6'])
final_data.head()
# Out:
#    Dimension 1  Dimension 2  Dimension 3  Dimension 4  Dimension 5  \
# 0     1.139078     0.446641    -0.352243     0.057771     0.137709
# 1    -0.041791    -0.128350    -0.241987     0.110416     0.046094
# 2     0.589459    -0.089754    -0.181113     0.109154     0.169460
# 3     1.617302     0.651455     0.108451    -0.496684     0.109043
# 4     0.174770     0.151689    -0.218486     0.287558     0.053417
#
#    Dimension 6
# 0     0.150639
# 1    -0.023687
# 2    -0.042409
# 3     0.414653
# 4    -0.249697

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.model_selection import KFold

# %%
clf1 = DecisionTreeClassifier()
clf2 =  RandomForestClassifier()
clf3 = LogisticRegression()
kf = KFold(n_splits = 5)

#split the data and train data with kfolds
for train_index , test_index in kf.split(final_data):
    x_train , x_test = final_data.iloc[train_index] , final_data.iloc[test_index]
    y_train , y_test = target.iloc[train_index],target.iloc[test_index]
    
    #fit the model and predict
    clf1.fit(x_train,y_train) #select classifier clf1,clf2,clf3
    prediction = clf1.predict(x_test)
    score = accuracy_score(y_test,prediction)
    f1 = f1_score(y_test , prediction ,average = 'weighted')
    
    print( 'Acurracy : ', score)
    print('F1 Score :', f1)
# Out:
# Acurracy :  0.8333333333333334
# F1 Score : 0.8344255133245959
# Acurracy :  0.8771929824561403
# F1 Score : 0.8768440988835726
# Acurracy :  0.956140350877193
# F1 Score : 0.9557216340067508
# Acurracy :  0.9210526315789473
# F1 Score : 0.9222848522110223
# Acurracy :  0.8407079646017699
# F1 Score : 0.8513827845465509
